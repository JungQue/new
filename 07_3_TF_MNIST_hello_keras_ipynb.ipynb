# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist #사람과 친함, 쉬움

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)), #flatten 평평하게 => 한줄로 만들기 총 784개의 칸 # 형상이 무시됨
  tf.keras.layers.Dense(256, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax) # 확률 그릇 10칸 #dense 다 연결함 ex)거미줄 밀도높음
])
# softmax 0~1 값 출력
# 값들은 다더하면 1
# 확률을 표현
# softmas(x)i=exp(xi)/시그마i * exp(xi) # 시험
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy']) # adam, momentum # 공굴리기=모멘텀 아담=절반의 모멘텀
# 공굴리기 가장 낮은곳을 찾아감 # 로컬 미니엄_정답'같이' 보이는 값, 글로벌 미니엄_정답 # 아담을 쓰자!!

# %% [markdown]
# 거미줄 문제
# 1. 형상 무시: 한줄로 만듬
# 2. 너무많은 거미줄
#
# convolution
# 입체 필터랑 겹치고 더함

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                2570
# ...
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs=5) # 모델을 돌림
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 10s 170us/sample - loss: 0.2244 - acc: 0.9359
# Epoch 2/5
# 60000/60000 [==============================] - 10s 167us/sample - loss: 0.0919 - acc: 0.9727
# Epoch 3/5
# 60000/60000 [==============================] - 10s 168us/sample - loss: 0.0627 - acc: 0.9805
# Epoch 4/5
# 60000/60000 [==============================] - 10s 168us/sample - loss: 0.0446 - acc: 0.9859
# Epoch 5/5
# 60000/60000 [==============================] - 10s 169us/sample - loss: 0.0341 - acc: 0.9892

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/10000 [==============================] - 1s 56us/sample - loss: 0.0769 - acc: 0.9783
# [0.07687149745568167, 0.9783]

# %% [markdown]
# #Training accuarcy

# %%
model.evaluate(x_train, y_train)
# Out:
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.0267 - acc: 0.9915
# [0.02670573550215146, 0.9915]
